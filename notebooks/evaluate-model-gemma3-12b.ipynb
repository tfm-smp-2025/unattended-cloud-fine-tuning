# %% [markdown]
# # Model evaluation notebook

# %%
# Jupyter version
import ipywidgets as widgets
from IPython.display import display

model_list = [
  "gemma2:2b",
  "gemma2:9b",
  "gemma3:12b",
  "mistral:7b",
  "mixtral:8x7b",
  "phi:2.7b",
  "phi4:14b",
  "deepseek-r1:7b",
]
model_picker = widgets.Dropdown(options=model_list)

# GColab version
MODEL = 'gemma3:12b' # @param ["gemma2:2b", "gemma2:9b", "gemma3:12b", "mistral:7b", "mixtral:8x7b", "phi:2.7b", "phi4:14b", "deepseek-r1:7b"] {allow-input: true}
MODEL
# Out:
# 'gemma3:12b'

# %%
# Start time
# !date
# Out:
# Mon Apr 28 05:15:16 PM UTC 2025

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install Ollama

# %% [markdown]
# #### Google Colab

# %%
# Google Collab dependencies from: https://github.com/5aharsh/collama
# !sudo apt update
# !sudo apt install -y pciutils
# !sh -c 'if which ollama; then echo Ollama already installed; else curl -fsSL https://ollama.com/install.sh | sh; fi'
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,864 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [46.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,542 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,844 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,155 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,701 kB]
# Fetched 20.8 MB in 5s (4,189 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 36 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (269 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package pci.ids.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# #### Docker image
# An ephemeral environment can be prepared with.
#
# ```shell
# docker run -v "${PWD}":/home/jovyan/work -it --rm -p 10000:8888 quay.io/jupyter/scipy-notebook:2025-03-14
# ```

# %% [markdown]
# If on Jupyter Docker image, run
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'apt update && apt install -y pciutils'
# ```

# %% [markdown]
# ##### Install Ollama
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'curl -fsSL https://ollama.com/install.sh | sh'
# ```

# %% [markdown]
# #### Prepare model

# %%
# Code taken from https://github.com/5aharsh/collama
import threading
import subprocess
import time
import socket

MAX_WAIT_SECONDS = 60
OLLAMA_PORT = 11434

def is_ollama_ready():
  s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
  try:
    s.connect(('localhost', OLLAMA_PORT))
    s.shutdown(socket.SHUT_RDWR)
    return True
  except:
    return False


def start_ollama_thread():
  def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])

  thread = threading.Thread(target=run_ollama_serve)
  thread.start()

  print("Waiting for OLLama to be ready...         ")

  for sec in range(MAX_WAIT_SECONDS):
    if is_ollama_ready():
      break
    print("\b\b\b\b\b\b\b\b\b" + "{:3d}s/{:3d}s".format(sec + 1, MAX_WAIT_SECONDS), end='', flush=True)
    time.sleep(1)
  print()

if not is_ollama_ready():
  start_ollama_thread()
# Out:
# Waiting for OLLama to be ready...
#   1s/ 60s

# %%
# !ollama pull "$MODEL"
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling e8ad13eff07a:   0% ▕▏  28 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   1% ▕▏  63 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   2% ▕▏ 124 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   2% ▕▏ 171 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   2% ▕▏ 183 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   2% ▕▏ 197 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   3% ▕▏ 282 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   4% ▕▏ 318 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   4% ▕▏ 365 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   5% ▕▏ 396 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   5% ▕▏ 421 MB/8.1 GB                  pulling manifest
# pulling e8ad13eff07a:   6% ▕▏ 453 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   6% ▕▏ 482 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   6% ▕▏ 504 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   6% ▕▏ 526 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   7% ▕▏ 565 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   7% ▕▏ 580 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   8% ▕▏ 613 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   8% ▕▏ 637 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:   8% ▕▏ 656 MB/8.1 GB  411 MB/s     18spulling manifest
# pulling e8ad13eff07a:
GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  89% ▕▏ 7.2 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  89% ▕▏ 7.3 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  89% ▕▏ 7.3 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.3 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.3 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  188 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  209 MB/s      3spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  90% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  91% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  91% ▕▏ 7.4 GB/8.1 GB  192 MB/s      4spulling manifest
# pulling e8ad13eff07a:  91% ▕▏ 7.4 GB/8.1 GB  192 MB/s      3spulling manifest
# pulling e8ad13eff07a:  92% ▕▏ 7.5 GB/8.1 GB  192 MB/s      3spulling manifest
# pulling e8ad13eff07a:  92% ▕▏ 7.5 GB/8.1 GB  192 MB/s      3spulling manifest
# pulling e8ad13eff07a:  93% ▕▏ 7.6 GB/8.1 GB  172 MB/s      3spulling manifest
# pulling e8ad13eff07a:  93% ▕▏ 7.6 GB/8.1 GB  172 MB/s      3spulling manifest
# pulling e8ad13eff07a:  94% ▕▏ 7.6 GB/8.1 GB  172 MB/s      2spulling manifest
# pulling e8ad13eff07a:  94% ▕▏ 7.7 GB/8.1 GB  172 MB/s      2spulling manifest
# pulling e8ad13eff07a:  95% ▕▏ 7.7 GB/8.1 GB  172 MB/s      2spulling manifest
# pulling e8ad13eff07a:  95% ▕▏ 7.7 GB/8.1 GB  172 MB/s      2spulling manifest
# pulling e8ad13eff07a:  96% ▕▏ 7.8 GB/8.1 GB  172 MB/s      2spulling manifest
# pulling e8ad13eff07a:  96% ▕▏ 7.8 GB/8.1 GB  172 MB/s      1spulling manifest
# pulling e8ad13eff07a:  96% ▕▏ 7.8 GB/8.1 GB  172 MB/s      1spulling manifest
# pulling e8ad13eff07a:  97% ▕▏ 7.9 GB/8.1 GB  172 MB/s      1spulling manifest
# pulling e8ad13eff07a:  97% ▕▏ 7.9 GB/8.1 GB  190 MB/s      1spulling manifest
# pulling e8ad13eff07a:  97% ▕▏ 7.9 GB/8.1 GB  190 MB/s      1spulling manifest
# pulling e8ad13eff07a:  97% ▕▏ 7.9 GB/8.1 GB  190 MB/s      1spulling manifest
# pulling e8ad13eff07a:  98% ▕▏ 8.0 GB/8.1 GB  190 MB/s      1spulling manifest
# pulling e8ad13eff07a:  98% ▕▏ 8.0 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  98% ▕▏ 8.0 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.0 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  190 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  210 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a:  99% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB/8.1 GB  193 MB/s      0spulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB/8.1 GB  160 MB/s      0spulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB/8.1 GB  160 MB/s      0spulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB/8.1 GB  160 MB/s      0spulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# ...
# verifying sha256 digest ⠏ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e8ad13eff07a: 100% ▕▏ 8.1 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling 6819964c2bcf: 100% ▕▏  490 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ### Prepare code

# %%
from getpass import getpass

def get_secret(prompt, secret_name, secret_input=True):
  try:
    from google.colab import userdata
    result = userdata.get(secret_name)
    assert result is not None
  except:
    if secret_input:
      result = getpass(prompt)
    else:
      result = input(prompt)
  return result

# %%
import os

if not os.path.exists('src'):
  import urllib

  user = get_secret('User name: ', 'TFM_GH_USER')
  password = get_secret('Password: ', 'TFM_GH_TOKEN')
  password = urllib.parse.quote(password) # your password is converted into url format
  repopath = "tfm-smp-2025/fine-tuning"

  # !git clone https://"$user":"$password"@github.com/"$repopath" src

  del password
# Out:
# Cloning into 'src'...
# remote: Enumerating objects: 674, done.
# remote: Counting objects: 100% (256/256), done.
# remote: Compressing objects: 100% (158/158), done.
# Receiving objects: 100% (674/674), 142.30 KiB | 11.86 MiB/s, done.
# remote: Total 674 (delta 172), reused 166 (delta 95), pack-reused 418 (from 1)
# Resolving deltas: 100% (429/429), done.

# %%
# Update code, if needed
# !cd src && git pull
# Out:
# Already up to date.

# %% [markdown]
# #### Dependencies

# %%
# !pip install -q -r src/requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 75.8 MB/s eta 0:00:00

# %% [markdown]
# ##### NLP model

# %%
try:
  import spacy
  spacy.load("en_core_web_md")
except:
  # !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 63.8 MB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# #### Credentials

# %% [markdown]
# ##### Result pusher setup

# %%
import os

if (
    (not os.path.exists(os.path.expanduser("~/.ssh/id_rsa")))
    or (not os.path.exists(os.path.expanduser("~/.ssh/known_hosts")))
):
  SSHKEY = get_secret('Result pusher SSH key: ', 'TFM_SSH_PUSHER_KEY')

  # !mkdir ~/.ssh

  # Read locally with `cat ~/.ssh/result-pusher|tr '\n' '$';echo`
  with open(os.path.expanduser("~/.ssh/id_rsa"), 'wt') as f:
    f.write(SSHKEY.replace('$', '\n'))

  # !chmod 0600 ~/.ssh/id_rsa
  # !ssh-keygen -y -f ~/.ssh/id_rsa > ~/.ssh/id_rsa.pub
  # !chmod 0600 ~/.ssh/id_rsa.pub

  # This won't copy the client key (not needed), but it will initialize the server's on the client
  # !ssh-copy-id -i ~/.ssh/id_rsa -o StrictHostKeyChecking=accept-new result-pusher@kb.tfm.codigoparallevar.com

  del SSHKEY
# Out:
# /usr/bin/ssh-copy-id: INFO: Source of key(s) to be installed: "/root/.ssh/id_rsa.pub"
# /usr/bin/ssh-copy-id: INFO: attempting to log in with the new key(s), to filter out any that are already installed
#
# /usr/bin/ssh-copy-id: WARNING: All keys were skipped because they already exist on the remote system.
# 		(if you think this is a mistake, you may want to use -f option)

# %% [markdown]
# ##### Patch SPARQL wrapper to use KB_PASSWORD

# %%
import os
if not os.getenv('KB_PASSWORD'):
  os.environ['KB_PASSWORD'] = get_secret('Password: ', 'TFM_KB_ADMIN_PASS')

# !export KB_PASSWORD=$KB_PASSWORD

# %%
# !sed 's/from urllib.request import/import base64, os\nfrom urllib.request import/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'
# !sed 's/request = self._createRequest()/request = self._createRequest()\n        base64string = base64.b64encode("{}:{}".format("admin", os.environ["KB_PASSWORD"]).encode())\n        request.add_header("Authorization", "Basic " + base64string.decode())/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'

# %% [markdown]
# ##### Setup WEAVIATE API KEY

# %%
import os
if not os.getenv('WEAVIATE_API_KEY'):
  os.environ['WEAVIATE_API_KEY'] = get_secret('Password: ', 'TFM_VECTOR_DB_ADMIN_APIKEY')

# !export WEAVIATE_API_KEY=$WEAVIATE_API_KEY

# %% [markdown]
# ### Pull datasets

# %%
# !python3 src/scripts/pull_datasets.py
# Out:
# qald-9 | Unified dataset...
#   ↓  Downloading qald-9 dataset
#   ✔  qald-9 dataset ready
#
# beastiary | Unified dataset...
#   ↓  Downloading beastiary dataset
#   ✔  beastiary dataset ready
#
# VQuAnDA | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 1.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 2.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# WebQuestions SP | Unified dataset...
#   ↓  Downloading WebQuestions SP dataset
#   ✔  WebQuestions SP dataset ready

# %% [markdown]
# ## Run evaluation

# %%
# Prepare profiler
# !pip install -q git+https://github.com/nickodell/python-flamegraph.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for flamegraph (setup.py) ... done

# %%
assert MODEL != ''

if not is_ollama_ready():
  start_ollama_thread()

# !time WEAVIATE_HOST=kb.tfm.codigoparallevar.com \
    python3 \
    -m flamegraph -o perf.log \
    src/src/as_script.py \
    --seed 42 \
    test --models="$MODEL" \
    --sparql-server 'http://kb.tfm.codigoparallevar.com' \
    --sample 10 \
    --dataset 'LC-QuAD 1.0'
# Out:
# Streaming output truncated to the last 5000 lines.
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# *   `http://dbpedia.org/resource/Dream_Dancer`
# ...
#         "http://dbpedia.org/property/children",
#         "http://dbpedia.org/ontology/growingGrape",
#         "http://dbpedia.org/ontology/ethnicity",
#         "http://dbpedia.org/ontology/Lake/areaOfCatchment",
#         "http://dbpedia.org/ontology/sisterNewspaper",
#         "http://dbpedia.org/property/childLeft",
#         "http://dbpedia.org/ontology/isPartOfAnatomicalStructure",
#         "http://dbpedia.org/ontology/actScore",
#         "http://dbpedia.org/property/plant",
#         "http://dbpedia.org/ontology/championInDoubleFemale",
#         "http://dbpedia.org/property/wineries",
#         "http://dbpedia.org/property/chalwins",
#         "http://dbpedia.org/ontology/child",
#         "http://dbpedia.org/property/familia",
#         "http://dbpedia.org/ontology/gender",
#         "http://dbpedia.org/property/plantType",
#         "http://dbpedia.org/property/plantCommission",
#         "http://dbpedia.org/property/maidens",
#         "http://dbpedia.org/property/entrezgene",
#     ...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:16.515413 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 1/3):
# Given that the entities being referenced are:
#
# ```json
# {
#     "L'Enfant": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/Pierre_Charles_L'Enfant",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/ethnicity"
#                 ]
#             }
#         ]
#     }
# }
# ```
#
# This are some examples on how the available properties can be used:
#
# ### Subject: <http://dbpedia.org/resource/Pierre_Charles_L'Enfant> ; Predicate: <http://dbpedia.org/ontology/ethnicity>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pierre_Charles_L'Enfant> <http://dbpedia.org/ontology/ethnicity> ?object }
# ```
#
# Of the ones given, which predicates will be useful to solve it?
#
# Consider it's better to query directly on IRIs and avoid filtering whenever possible. DO NOT generate any query yet.
#
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"L'Enfant\": {\...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:23.493160 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: Given the context and the goal of directly querying IRIs and avoiding filtering, the most useful predicate from the provided example is:
#
# *   `http://dbpedia.org/ontology/ethnicity`
#
# This predicate directly links to a property of the subject "Pierre Charles L'Enfant," allowing for a targeted query to retrieve information about his ethnicity. This is a clear and direct way to extract relevant data. The other predicates are not provided, so we can't evaluate their usefulness.
#
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"L'Enfant\": {\...
#     "output": "Given the context and the goal of directly querying IRIs and avoiding filtering, t...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:23.493489 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 2/3): What are the subject IRIs that will be handy to solve this query? STILL DO NOT generate any query yet.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:40.384575 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: Based on the query "Who created the Women in the Garden and also the L'Enfant a la tasse ?", and considering the provided information about "L'Enfant", the following subject IRIs would be useful:
#
# *   `http://dbpedia.org/resource/Pierre_Charles_L'Enfant` - This is the subject we already have information about, and is likely related to "L'Enfant a la tasse".
# *   We need to identify the IRI for "Women in the Garden". Since we don't have any information about it, we're assuming it refers to a specific artwork or group of people. We'd need to search for the IRI representing "Women in the Garden" within the knowledge graph. Let's assume for now that the IRI is `http://example.org/women_in_the_garden` (this is a placeholder, and would need to be replaced with the actual IRI).
#
# Therefore, the subject IRIs to consider are:
#
# *   `http://dbpedia.org/resource/Pierre_Charles_L'Enfant`
# *   `http://example.org/women_in_the_garden` (Placeholder - needs to be replaced with the actual IRI)
#
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
#     "output": "Based on the query \"Who created the Women in the Garden and also the L'Enfant a l...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:40.385035 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 3/3):
# Construct a SPARQL query to solve it on a single query, keep it simple and avoid unnecessary conditions. If it's an item list just do a SELECT, but if it's numeric you might need to use a verb like COUNT(), and if it's boolean you might need to use ASK.
#
# Remember to avoid querying by label, use the IRIs and relations presented before, not others. DO NOT even use common types like `name` or `type` unless they were explicitly allowed.
#
# Query to solve:
# > Who created the Women in the Garden and also the L'Enfant a la tasse ?
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:49.049035 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: ```sparql
# CONSTRUCT {
#   ?creator rdfs:label ?label .
# }
# WHERE {
#   {
#     ?artwork1 rdfs:label "Women in the Garden" .
#     ?artwork1 <http://schema.org/creator> ?creator .
#   }
#   UNION
#   {
#     ?artwork2 rdfs:label "L'Enfant a la tasse" .
#     ?artwork2 <http://schema.org/creator> ?creator .
#   }
# }
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
#     "output": "```sparql\nCONSTRUCT {\n  ?creator rdfs:label ?label .\n}\nWHERE {\n  {\n    ?artw...
# }
# ---------- >8 ----------
# Final query: CodeBlock(language='sparql', content='CONSTRUCT {\n  ?creator rdfs:label ?label .\n}\nWHERE {\n  {\n    ?artwork1 rdfs:label "Women in the Garden" .\n    ?artwork1 <http://schema.org/creator> ?creator .\n  }\n  UNION\n  {\n    ?artwork2 rdfs:label "L\'Enfant a la tasse" .\n    ?artwork2 <http://schema.org/creator> ?creator .\n  }\n}\n')
# 2025-04-28T18:58:49.049724 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Translated query: CodeBlock(language='sparql', content='CONSTRUCT {\n  ?creator rdfs:label ?label .\n}\nWHERE {\n  {\n    ?artwork1 rdfs:label "Women in the Garden" .\n    ?artwork1 <http://schema.org/creator> ?creator .\n  }\n  UNION\n  {\n    ?artwork2 rdfs:label "L\'Enfant a la tasse" .\n    ?artwork2 <http://schema.org/creator> ?creator .\n  }\n}\n')
# ---------- 8< ---------- DATA
# [
#     "sparql",
#     "CONSTRUCT {\n  ?creator rdfs:label ?label .\n}\nWHERE {\n  {\n    ?artwork1 rdfs:label \"Wom...
# ]
# ---------- >8 ----------
# Querying: CONSTRUCT { ?creator rdfs:label ?label . } WHERE { { ?artwork1 rdfs:la/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py:795: RuntimeWarning: Sending Accept header '*/*' because unexpected returned format 'json' in a 'CONSTRUCT' SPARQL query form
#   warnings.warn(
# 2025-04-28T18:58:49.436301 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 Error SPARQL query: CONSTRUCT {
#   ?creator rdfs:label ?label .
# }
# WHERE {
#   {
#     ?artwork1 rdfs:label "Women in the Garden" .
#     ?artwork1 <http://schema.org/creator> ?creator .
#   }
#   UNION
#   {
#     ?artwork2 rdfs:label "L'Enfant a la tasse" .
#     ?artwork2 <http://schema.org/creator> ?creator .
#   }
# }
#
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 929, in _query
#     response = urlopener(request)
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/src/src/ontology.py", line 64, in run_query
#     ret = sparql.queryAndConvert()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 970, in queryAndConvert
#     res = self.query()
#           ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 963, in query
#     return QueryResult(self._query())
#                        ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 933, in _query
#     raise QueryBadFormed(e.read())
# SPARQLWrapper.SPARQLExceptions.QueryBadFormed: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Parse error: Line 2, column 12: Unresolved prefixed name: rdfs:label\n'
#
# ---------- >8 ----------
# ---------- 8< ---------- DATA
# {
#     "query": "CONSTRUCT {\n  ?creator rdfs:label ?label .\n}\nWHERE {\n  {\n    ?artwork1 rdfs:la...
# }
# ---------- >8 ----------
# 2025-04-28T18:58:49.437650 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 929, in _query
#     response = urlopener(request)
#                ^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# urllib.error.HTTPError: HTTP Error 400: Bad Request
#
#
# During handling of the above exception, another exception occurred:
#
#
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 136, in run_test
#     translator_result = ontology.run_query(
#                         ^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/ontology.py", line 64, in run_query
#     ret = sparql.queryAndConvert()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 970, in queryAndConvert
#     res = self.query()
#           ^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 963, in query
#     return QueryResult(self._query())
#                        ^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py", line 933, in _query
#     raise QueryBadFormed(e.read())
#
# SPARQLWrapper.SPARQLExceptions.QueryBadFormed: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Parse error: Line 2, column 12: Unresolved prefixed name: rdfs:label\n'
#
# ---------- >8 ----------
# 2025-04-28T18:58:49.437820 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Who created the Women in the Garden and also the L'Enfant a la tasse ?",
#     "expected_query": "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Women_in_the_Gar...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Claude_Monet"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-28T18:58:49.438160 [[Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-9](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "gemma3:12b"
#         },
#         "question": [
#             "Who created the Women in the Garden and also the L'Enfant a la tasse ?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Women_in_the_Garden> <http...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "8ea33332-ae69-4e0f-a7eb-453641f309bd"
#     }
# }
# ---------- >8 ----------
#   1% 10/1000 [1:39:49<125:00:44, 454.59s/it]2025-04-28T18:58:49.438521 [[Q-10](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-10](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "gemma3:12b"
#         },
#         "question": [
#             "Which famous horserace has seen both Fergie sutherland and the illustrious War of At...
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/War_Of_Attrition_(horse)> ...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "31693dec-7f77-4f11-ab59-948bab61511e"
#     }
# }
# ---------- >8 ----------
# 2025-04-28T18:58:49.438725 [[Q-10](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-10](gemma3:12b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "gemma3:12b"
#         },
#         "question": [
#             "Which famous horserace has seen both Fergie sutherland and the illustrious War of At...
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/War_Of_Attrition_(horse)> ...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "31693dec-7f77-4f11-ab59-948bab61511e"
#     }
# }
# ---------- >8 ----------
#   1% 10/1000 [1:39:49<164:42:23, 598.93s/it]
# Elapsed Time: 5997.03 seconds.  Collected 4429212 stack frames (946 unique)
#
# real	100m0.159s
# user	15m43.865s
# sys	2m51.266s

# %% [markdown]
# ## Upload results

# %%
import os
import time
if os.path.exists('perf.log'):
  new_perf_path = 'perf-{}.log'.format(int(time.time()))
  os.rename('perf.log', new_perf_path)
  # !rsync -HPrz --mkpath \
    "$new_perf_path" \
    result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/perfs
# Out:
# sending incremental file list
# perf-1745866732.log
#       2,262,274 100%    1.04GB/s    0:00:00 (xfr#1, to-chk=0/1)

# %%
# !rsync -HPrz --mkpath \
  src/experiment-viewer/logs/ \
  result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/logs
# Out:
# sending incremental file list
# .gitignore
#              13 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=1/3)
# log-2025-04-28 17:19:00.085748.jsonl
#         972,692 100%  309.21MB/s    0:00:00 (xfr#2, to-chk=0/3)

# %% [markdown]
# ## Cleanup

# %%
# Finish time
# !date
# Out:
# Mon Apr 28 06:59:00 PM UTC 2025

# %% [markdown]
# ### Stop kernel

# %%
# exit(0)
