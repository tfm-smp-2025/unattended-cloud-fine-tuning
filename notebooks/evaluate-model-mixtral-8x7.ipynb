# %% [markdown]
# # Model evaluation notebook

# %%
# Jupyter version
import ipywidgets as widgets
from IPython.display import display

model_list = [
  "gemma2:2b",
  "gemma2:9b",
  "gemma3:12b",
  "mistral:7b",
  "mixtral:8x7b",
  "phi:2.7b",
  "phi4:14b",
  "deepseek-r1:7b",
]
model_picker = widgets.Dropdown(options=model_list)

# GColab version
MODEL = 'mixtral:8x7b' # @param ["gemma2:2b", "gemma2:9b", "gemma3:12b", "mistral:7b", "mixtral:8x7b", "phi:2.7b", "phi4:14b", "deepseek-r1:7b"] {allow-input: true}
MODEL
# Out:
# 'mixtral:8x7b'

# %%
# Start time
# !date
# Out:
# Sun Apr 27 09:46:18 PM UTC 2025

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install Ollama

# %% [markdown]
# #### Google Colab

# %%
# Google Collab dependencies from: https://github.com/5aharsh/collama
# !sudo apt update
# !sudo apt install -y pciutils
# !sh -c 'if which ollama; then echo Ollama already installed; else curl -fsSL https://ollama.com/install.sh | sh; fi'
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 35 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pciutils is already the newest version (1:3.7.0-6).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# /usr/local/bin/ollama
# Ollama already installed

# %% [markdown]
# #### Docker image
# An ephemeral environment can be prepared with.
#
# ```shell
# docker run -v "${PWD}":/home/jovyan/work -it --rm -p 10000:8888 quay.io/jupyter/scipy-notebook:2025-03-14
# ```

# %% [markdown]
# If on Jupyter Docker image, run
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'apt update && apt install -y pciutils'
# ```

# %% [markdown]
# ##### Install Ollama
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'curl -fsSL https://ollama.com/install.sh | sh'
# ```

# %% [markdown]
# #### Prepare model

# %%
# Code taken from https://github.com/5aharsh/collama
import threading
import subprocess
import time
import socket

MAX_WAIT_SECONDS = 60
OLLAMA_PORT = 11434

def is_ollama_ready():
  s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
  try:
    s.connect(('localhost', OLLAMA_PORT))
    s.shutdown(socket.SHUT_RDWR)
    return True
  except:
    return False


def start_ollama_thread():
  def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])

  thread = threading.Thread(target=run_ollama_serve)
  thread.start()

  print("Waiting for OLLama to be ready...         ")

  for sec in range(MAX_WAIT_SECONDS):
    if is_ollama_ready():
      break
    print("\b\b\b\b\b\b\b\b\b" + "{:3d}s/{:3d}s".format(sec + 1, MAX_WAIT_SECONDS), end='', flush=True)
    time.sleep(1)
  print()

if not is_ollama_ready():
  start_ollama_thread()
# Out:
# Waiting for OLLama to be ready...
#   1s/ 60s

# %%
# !ollama pull "$MODEL"
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest
# writing manifest
# success
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ### Prepare code

# %%
from getpass import getpass

def get_secret(prompt, secret_name, secret_input=True):
  try:
    from google.colab import userdata
    result = userdata.get(secret_name)
    assert result is not None
  except:
    if secret_input:
      result = getpass(prompt)
    else:
      result = input(prompt)
  return result

# %%
import os

if not os.path.exists('src'):
  import urllib

  user = get_secret('User name: ', 'TFM_GH_USER')
  password = get_secret('Password: ', 'TFM_GH_TOKEN')
  password = urllib.parse.quote(password) # your password is converted into url format
  repopath = "tfm-smp-2025/fine-tuning"

  # !git clone https://"$user":"$password"@github.com/"$repopath" src

  del password
# Out:
# Cloning into 'src'...
# remote: Enumerating objects: 674, done.
# remote: Counting objects: 100% (256/256), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 674 (delta 172), reused 166 (delta 95), pack-reused 418 (from 1)
# Receiving objects: 100% (674/674), 142.30 KiB | 818.00 KiB/s, done.
# Resolving deltas: 100% (429/429), done.

# %%
# Update code, if needed
# !cd src && git pull
# Out:
# Already up to date.
# Already up to date.

# %% [markdown]
# #### Dependencies

# %%
# !pip install -q -r src/requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 37.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 93.4 MB/s eta 0:00:00

# %% [markdown]
# ##### NLP model

# %%
try:
  import spacy
  spacy.load("en_core_web_md")
except:
  # !python -m spacy download en_core_web_md

# %% [markdown]
# #### Credentials

# %% [markdown]
# ##### Result pusher setup

# %%
import os

if (
    (not os.path.exists(os.path.expanduser("~/.ssh/id_rsa")))
    or (not os.path.exists(os.path.expanduser("~/.ssh/known_hosts")))
):
  SSHKEY = get_secret('Result pusher SSH key: ', 'TFM_SSH_PUSHER_KEY')

  # !mkdir ~/.ssh

  # Read locally with `cat ~/.ssh/result-pusher|tr '\n' '$';echo`
  with open(os.path.expanduser("~/.ssh/id_rsa"), 'wt') as f:
    f.write(SSHKEY.replace('$', '\n'))

  # !chmod 0600 ~/.ssh/id_rsa
  # !ssh-keygen -y -f ~/.ssh/id_rsa > ~/.ssh/id_rsa.pub
  # !chmod 0600 ~/.ssh/id_rsa.pub

  # This won't copy the client key (not needed), but it will initialize the server's on the client
  # !ssh-copy-id -i ~/.ssh/id_rsa -o StrictHostKeyChecking=accept-new result-pusher@kb.tfm.codigoparallevar.com

  del SSHKEY

# %% [markdown]
# ##### Patch SPARQL wrapper to use KB_PASSWORD

# %%
import os
if not os.getenv('KB_PASSWORD'):
  os.environ['KB_PASSWORD'] = get_secret('Password: ', 'TFM_KB_ADMIN_PASS')

# !export KB_PASSWORD=$KB_PASSWORD

# %%
# !sed 's/from urllib.request import/import base64, os\nfrom urllib.request import/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'
# !sed 's/request = self._createRequest()/request = self._createRequest()\n        base64string = base64.b64encode("{}:{}".format("admin", os.environ["KB_PASSWORD"]).encode())\n        request.add_header("Authorization", "Basic " + base64string.decode())/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'

# %% [markdown]
# ##### Setup WEAVIATE API KEY

# %%
import os
if not os.getenv('WEAVIATE_API_KEY'):
  os.environ['WEAVIATE_API_KEY'] = get_secret('Password: ', 'TFM_VECTOR_DB_ADMIN_APIKEY')

# !export WEAVIATE_API_KEY=$WEAVIATE_API_KEY

# %% [markdown]
# ### Pull datasets

# %%
# !python3 src/scripts/pull_datasets.py
# Out:
# qald-9 | Unified dataset...
#   ↓  Downloading qald-9 dataset
#   ✔  qald-9 dataset ready
#
# beastiary | Unified dataset...
#   ↓  Downloading beastiary dataset
#   ✔  beastiary dataset ready
#
# VQuAnDA | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 1.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 2.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# WebQuestions SP | Unified dataset...
#   ↓  Downloading WebQuestions SP dataset
#   ✔  WebQuestions SP dataset ready
#
# qald-9 | Unified dataset...
#   ✔ qald-9 unified dataset present
#
# beastiary | Unified dataset...
#   ✔ beastiary unified dataset present
#
# VQuAnDA | Split dataset...
#   ✔  Train file present
#   ✔  Test file present
#
# LC-QuAD 1.0 | Split dataset...
#   ✔  Train file present
#   ✔  Test file present
#
# LC-QuAD 2.0 | Split dataset...
#   ✔  Train file present
#   ✔  Test file present
#
# WebQuestions SP | Unified dataset...
#   ↓  Downloading WebQuestions SP dataset
#   ✔  WebQuestions SP dataset ready

# %% [markdown]
# ## Run evaluation

# %%
# Prepare profiler
# !pip install -q git+https://github.com/nickodell/python-flamegraph.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for flamegraph (setup.py) ... done
#   Preparing metadata (setup.py) ... done

# %%
assert MODEL != ''

if not is_ollama_ready():
  start_ollama_thread()

# !time WEAVIATE_HOST=kb.tfm.codigoparallevar.com \
    python3 \
    -m flamegraph -o perf.log \
    src/src/as_script.py \
    --seed 42 \
    test --models="$MODEL" \
    --sparql-server 'http://kb.tfm.codigoparallevar.com' \
    --sample 100 \
    --dataset 'LC-QuAD 1.0'
# Out:
# Streaming output truncated to the last 5000 lines.
#
# > Did Timm Gunn guest in Sunrise (HIMYM)?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Did Timm Gunn guest in Sun...
# }
# ---------- >8 ----------
# 2025-04-27T21:55:40.478538 [[Q-63](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "Timm Gunn",
#     "Sunrise",
#     "HIMYM"
# ]
#
# Here, "Timm Gunn" and "Sunrise" are proper nouns referring to specific entities, while "HIMYM" is an abbreviation for a TV show.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Did Timm Gunn guest in Sun...
#     "output": "\n[\n    \"Timm Gunn\",\n    \"Sunrise\",\n    \"HIMYM\"\n]\n\nHere, \"Timm Gunn\"...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:55:40.479328 [[Q-63](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:55:40.479452 [[Q-63](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Did Timm Gunn guest in Sunrise (HIMYM)?",
#     "expected_query": "ASK WHERE { <http://dbpedia.org/resource/Sunrise_(How_I_Met_Your_Mother)> ...
#     "expected_result": true,
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:55:40.479556 [[Q-63](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-63](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Did Timm Gunn guest in Sunrise (HIMYM)?",
#             "ASK WHERE { <http://dbpedia.org/resource/Sunrise_(How_I_Met_Your_Mother)> <http://db...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "5562e09b-c30e-4975-af14-fb08de5c9513"
#     }
# }
# ---------- >8 ----------
#   6% 64/1000 [09:06<1:56:08,  7.44s/it]2025-04-27T21:55:40.479819 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "to which university did both, the Stanford Cardinal and Gerald Reaven go?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Stanford_Cardinal> <http:...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "7176f954-0c21-43b1-ace6-f172c42f2583"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:55:40.480117 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: to which university did both, the Stanford Cardinal and Gerald Reaven go?
# ---------- 8< ---------- DATA
# "to which university did both, the Stanford Cardinal and Gerald Reaven go?"
# ---------- >8 ----------
# 2025-04-27T21:55:40.819366 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Stanford_University'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Stanford_University"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:55:40.819502 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > to which university did both, the Stanford Cardinal and Gerald Reaven go?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> to which university did bo...
# }
# ---------- >8 ----------
# 2025-04-27T21:55:53.593773 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "university",
#     "Stanford Cardinal",
#     "Gerald Reaven"
# ]
#
# Explanation: The nouns in the query are "university", "Stanford Cardinal", and "Gerald Reaven". The SPARQL verb in this context would be something like "attend" or "belong to", but since there's no need for a specific SPARQL verb, we can simply extract the nouns.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> to which university did bo...
#     "output": "\n[\n    \"university\",\n    \"Stanford Cardinal\",\n    \"Gerald Reaven\"\n]\n\n...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:55:53.594571 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:55:53.594680 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "to which university did both, the Stanford Cardinal and Gerald Reaven go?",
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Stanford_Cardin...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Stanford_University"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:55:53.594828 [[Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-64](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "to which university did both, the Stanford Cardinal and Gerald Reaven go?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Stanford_Cardinal> <http:...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "7176f954-0c21-43b1-ace6-f172c42f2583"
#     }
# }
# ---------- >8 ----------
#   6% 65/1000 [09:19<2:22:31,  9.15s/it]2025-04-27T21:55:53.595136 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Name the nearest city to David W. Brown House ?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/David_W._Brown_House> <ht...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "95fd1488-bcd2-4fee-905d-13e7dce8043a"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:55:53.595398 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Name the nearest city to David W. Brown House ?
# ---------- 8< ---------- DATA
# "Name the nearest city to David W. Brown House ?"
# ---------- >8 ----------
# 2025-04-27T21:55:53.934591 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Colorado'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Arapahoe_County,_Colorado'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Englewood,_Colorado'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Colorado"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arapahoe_County,_Colorado"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Englewood,_Colorado"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:55:53.934752 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Name the nearest city to David W. Brown House ?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Name the nearest city to D...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:05.832326 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "nearest city",
#     "David W. Brown House"
# ]
#
# Explanation: The nouns in the query are "Name", "nearest city", and "David W. Brown House". We can ignore "Name" as it's likely to be a SPARQL verb indicating what kind of information is being requested. So, we keep only "nearest city" and "David W. Brown House" in the list.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Name the nearest city to D...
#     "output": "\n[\n    \"nearest city\",\n    \"David W. Brown House\"\n]\n\nExplanation: The no...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:05.833322 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:05.833437 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Name the nearest city to David W. Brown House ?",
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/David_W._Brown_...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Colorado"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Arapahoe_County,_Colorado"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Englewood,_Colorado"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:56:05.833601 [[Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-65](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Name the nearest city to David W. Brown House ?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/David_W._Brown_House> <ht...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "95fd1488-bcd2-4fee-905d-13e7dce8043a"
#     }
# }
# ---------- >8 ----------
#   7% 66/1000 [09:32<2:36:48, 10.07s/it]2025-04-27T21:56:05.833851 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "where did Deion Sanders debut?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Deion_Sanders> <http://db...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "ee144fdd-4d61-49b7-b74d-b0be600d887a"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:05.834157 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: where did Deion Sanders debut?
# ---------- 8< ---------- DATA
# "where did Deion Sanders debut?"
# ---------- >8 ----------
# 2025-04-27T21:56:06.173551 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/New_York_Yankees'}}, {'uri': {'type': 'literal', 'xml:lang': 'en', 'value': 'Atlanta Falcons'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/New_York_Yankees"
#         }
#     },
#     {
#         "uri": {
#             "type": "literal",
#             "xml:lang": "en",
#             "value": "Atlanta Falcons"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:06.173723 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > where did Deion Sanders debut?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> where did Deion Sanders de...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:16.394445 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "Deion Sanders",
#     "debut"
# ]
#
# Explanation: The nouns in the query are "Deion Sanders" and "debut". However, "debut" can be considered as a SPARQL verb since it represents an action or event. Therefore, the final list of nouns includes only "Deion Sanders".
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> where did Deion Sanders de...
#     "output": "\n[\n    \"Deion Sanders\",\n    \"debut\"\n]\n\nExplanation: The nouns in the que...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:16.395283 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:16.395416 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "where did Deion Sanders debut?",
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Deion_Sanders> ...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/New_York_Yankees"
#             }
#         },
#         {
#             "uri": {
#                 "type": "literal",
#                 "xml:lang": "en",
#                 "value": "Atlanta Falcons"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:56:16.395559 [[Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-66](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "where did Deion Sanders debut?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Deion_Sanders> <http://db...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "ee144fdd-4d61-49b7-b74d-b0be600d887a"
#     }
# }
# ---------- >8 ----------
#   7% 67/1000 [09:42<2:38:55, 10.22s/it]2025-04-27T21:56:16.395821 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "What cities are nearer to Fuountain Lake Farm?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Fountain_Lake_Farm> <http...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "45f217f8-a5fe-4384-969f-623ac54fb9dc"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:16.396012 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: What cities are nearer to Fuountain Lake Farm?
# ---------- 8< ---------- DATA
# "What cities are nearer to Fuountain Lake Farm?"
# ---------- >8 ----------
# 2025-04-27T21:56:16.735407 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/North_America'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Wisconsin'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montello,_Wisconsin'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/United_States'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/North_America"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Wisconsin"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Montello,_Wisconsin"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/United_States"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:16.735857 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > What cities are nearer to Fuountain Lake Farm?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> What cities are nearer to ...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:26.961530 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "cities",
#     "Fuountain Lake Farm"
# ]
#
# In the sentence "What cities are nearer to Fuountain Lake Farm?", the nouns are "cities" and "Fuountain Lake Farm". The verb in this context is "nearer", which implies a spatial relationship between the cities and Fuountain Lake Farm.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> What cities are nearer to ...
#     "output": "\n[\n    \"cities\",\n    \"Fuountain Lake Farm\"\n]\n\nIn the sentence \"What cit...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:26.962322 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:26.962434 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "What cities are nearer to Fuountain Lake Farm?",
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Fountain_Lake_F...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/North_America"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Wisconsin"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Montello,_Wisconsin"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/United_States"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:56:26.962595 [[Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-67](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "What cities are nearer to Fuountain Lake Farm?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Fountain_Lake_Farm> <http...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "45f217f8-a5fe-4384-969f-623ac54fb9dc"
#     }
# }
# ---------- >8 ----------
#   7% 68/1000 [09:53<2:40:22, 10.32s/it]2025-04-27T21:56:26.963029 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Who are the characters of Batman Live?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Batman_Live> <http://dbpe...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "9378a159-4302-47ef-acc0-c949af59647f"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:26.963254 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Who are the characters of Batman Live?
# ---------- 8< ---------- DATA
# "Who are the characters of Batman Live?"
# ---------- >8 ----------
# 2025-04-27T21:56:27.304054 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Batman'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Poison_Ivy_(comics)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Joker_(comics)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Robin_(comics)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Penguin_(comics)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Harley_Quinn'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Scarecrow_(DC_Comics)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Riddler'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Catwoman'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Two-Face'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Alfred_Pennyworth'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_Gordon_(comics)'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Batman"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Poison_Ivy_(comics)"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Joker_(comics)"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Robin_(comics)"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Penguin_(comics)"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Harley_Quinn"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#     ...
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:27.304578 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Who are the characters of Batman Live?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Who are the characters of ...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:36.053769 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "characters",
#     "Batman",
#     "Live"
# ]
#
# Here, "characters" is a noun indicating what the user wants to know about. "Batman" and "Live" are proper nouns referring to specific entities related to the user's query.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Who are the characters of ...
#     "output": "\n[\n    \"characters\",\n    \"Batman\",\n    \"Live\"\n]\n\nHere, \"characters\"...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:36.054612 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:36.054723 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Who are the characters of Batman Live?",
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Batman_Live> <h...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Batman"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Poison_Ivy_(comics)"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Joker_(comics)"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Robin_(comics)"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Penguin_(comics)"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Harley_Quinn"
#             }
#         },
#     ...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:36.055035 [[Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-68](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Who are the characters of Batman Live?",
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Batman_Live> <http://dbpe...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "9378a159-4302-47ef-acc0-c949af59647f"
#     }
# }
# ---------- >8 ----------
#   7% 69/1000 [10:02<2:34:27,  9.95s/it]2025-04-27T21:56:36.055418 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which artists trained in San Francisco Art Institute?",
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/training> <http://dbpe...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "ec6c5bb2-915d-4236-888b-8ddccf22fb1f"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:36.055570 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Which artists trained in San Francisco Art Institute?
# ---------- 8< ---------- DATA
# "Which artists trained in San Francisco Art Institute?"
# ---------- >8 ----------
# 2025-04-27T21:56:36.395647 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Emily_Carr'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jess_Collins'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Michael_Heizer'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Robert_Graham_(sculptor)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Thom_Merrick'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Arthur_Frank_Mathews'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/T._C._Cannon'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ronnie_Landfield'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Doris_Lee'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jason_Rhoades'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Edith_Heath'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Kovál'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Joan_Brown'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Reginato'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Manuel_Neri'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ronald_Davis'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jim_Franklin_(artist)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Helen_Hyde'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Paul_McCarthy'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Gregory_Gillespie'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Reminisce_(artist)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Karl_Kasten'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Adelaide_Hanscom_Leeson'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/William_T._Wiley'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_Zar'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Vena_Kava'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Annie_Leibovitz'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Robert_H._Hudson'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Forakis'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ralph_Stackpole'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ernest_Peixotto'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tullio_DeSantis'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Gladys_Rockmore_Davis'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ray_Strong'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Deborah_Remington'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Neil_Williams_(artist)'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Walter_Kuhlman'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Carlos_Vierra'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Sarah_Cain'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lin_Evola'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lynn_Marie_Kirby'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Daniela_Franco'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Carlos_Villa'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Emily_Carr"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Jess_Collins"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Michael_Heizer"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Robert_Graham_(sculptor)"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Thom_Merrick"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arthur_Frank_Mathews"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#     ...
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:36.396420 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Which artists trained in San Francisco Art Institute?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which artists trained in S...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:39.716840 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "artists",
#     "San Francisco Art Institute"
# ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which artists trained in S...
#     "output": "\n[\n    \"artists\",\n    \"San Francisco Art Institute\"\n]"
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:39.717613 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:39.717739 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Which artists trained in San Francisco Art Institute?",
#     "expected_query": "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/training> <h...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Emily_Carr"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Jess_Collins"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Michael_Heizer"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Robert_Graham_(sculptor)"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Thom_Merrick"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Arthur_Frank_Mathews"
#             }
#         },
#     ...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:39.718402 [[Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-69](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which artists trained in San Francisco Art Institute?",
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/training> <http://dbpe...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "ec6c5bb2-915d-4236-888b-8ddccf22fb1f"
#     }
# }
# ---------- >8 ----------
#   7% 70/1000 [10:05<2:05:02,  8.07s/it]2025-04-27T21:56:39.718664 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "What is the owning organisation of the Ford Kansas City Assembly Plant and also the ...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Ford_Kansas_City_Assembly...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "5d2185b6-4aba-4923-b71b-888a3aa5a7a4"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:39.718809 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: What is the owning organisation of the Ford Kansas City Assembly Plant and also the builder of the Ford Y-block engine?
# ---------- 8< ---------- DATA
# "What is the owning organisation of the Ford Kansas City Assembly Plant and also the builder of t...
# ---------- >8 ----------
# 2025-04-27T21:56:40.057859 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ford_Motor_Company'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Ford_Motor_Company"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:40.058055 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > What is the owning organisation of the Ford Kansas City Assembly Plant and also the builder of the Ford Y-block engine?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> What is the owning organis...
# }
# ---------- >8 ----------
# 2025-04-27T21:56:45.276640 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "owning organization",
#     "Ford Kansas City Assembly Plant",
#     "builder",
#     "Ford Y-block engine"
# ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> What is the owning organis...
#     "output": "\n[\n    \"owning organization\",\n    \"Ford Kansas City Assembly Plant\",\n    \...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T21:56:45.277443 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T21:56:45.277547 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "What is the owning organisation of the Ford Kansas City Assembly Plant and also the...
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Ford_Kansas_Cit...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Ford_Motor_Company"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T21:56:45.277679 [[Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-70](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "What is the owning organisation of the Ford Kansas City Assembly Plant and also the ...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Ford_Kansas_City_Assembly...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "5d2185b6-4aba-4923-b71b-888a3aa5a7a4"
#     }
# }
# ---------- >8 ----------
#   7% 71/1000 [10:11<1:53:15,  7.31s/it]2025-04-27T21:56:45.277997 [[Q-71](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-71](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Name the country with currency as Aureus ?",
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/currency> <http://dbpe...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "884038ed-de70-4937-9d6c-bcd2d372f54a"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T21:56:45.278256 [[Q-71](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Name the country with currency as Aureus ?
# ---------- 8< ---------- DATA
# "Name the country with currency as Aureus ?"
# ---------- >8 ----------
# 2025-04-27T21:56:45.616357 [[Q-71](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Roman_Empire'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/History_of_the_Roman_Empire'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Roman_Empire"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/History_of_the_Roman_Empire"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T21:56:45.616520 [[Q-71](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Name the country with currency as Aureus ?
#
# ...
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Name the movies for which music was given by  Geoffrey Burgon and distributed by  Ci...
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/music> <http://dbpedia...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "12e477b3-6a76-44d1-a916-2ac704f83ba8"
#     }
# }
# ---------- >8 ----------
#  10% 97/1000 [13:35<1:51:35,  7.41s/it]2025-04-27T22:00:09.528164 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Is Henry David Thoreau interested in Politics?",
#             "ASK WHERE { <http://dbpedia.org/resource/Henry_David_Thoreau> <http://dbpedia.org/pr...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "d2ec595d-1c60-483e-afe2-20ef53f8d512"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T22:00:09.528297 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Is Henry David Thoreau interested in Politics?
# ---------- 8< ---------- DATA
# "Is Henry David Thoreau interested in Politics?"
# ---------- >8 ----------
# 2025-04-27T22:00:09.866444 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: True
# ---------- 8< ---------- DATA
# true
# ---------- >8 ----------
# 2025-04-27T22:00:09.866569 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Is Henry David Thoreau interested in Politics?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Is Henry David Thoreau int...
# }
# ---------- >8 ----------
# 2025-04-27T22:00:13.508063 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "Henry David Thoreau",
#     "Politics"
# ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Is Henry David Thoreau int...
#     "output": "\n[\n    \"Henry David Thoreau\",\n    \"Politics\"\n]"
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T22:00:13.508680 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T22:00:13.508810 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Is Henry David Thoreau interested in Politics?",
#     "expected_query": "ASK WHERE { <http://dbpedia.org/resource/Henry_David_Thoreau> <http://dbpe...
#     "expected_result": true,
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T22:00:13.509044 [[Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-97](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Is Henry David Thoreau interested in Politics?",
#             "ASK WHERE { <http://dbpedia.org/resource/Henry_David_Thoreau> <http://dbpedia.org/pr...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "d2ec595d-1c60-483e-afe2-20ef53f8d512"
#     }
# }
# ---------- >8 ----------
#  10% 98/1000 [13:39<1:35:58,  6.38s/it]2025-04-27T22:00:13.509301 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Among the companies who has product named Chinook who has a key person as Dennis Mui...
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/keyPeople> <http://dbp...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "f56e456a-79a5-4ad4-9150-eb792f37c398"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T22:00:13.509451 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Among the companies who has product named Chinook who has a key person as Dennis Muilenburg ?
# ---------- 8< ---------- DATA
# "Among the companies who has product named Chinook who has a key person as Dennis Muilenburg ?"
# ---------- >8 ----------
# 2025-04-27T22:00:13.848174 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Boeing'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Boeing"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T22:00:13.848329 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Among the companies who has product named Chinook who has a key person as Dennis Muilenburg ?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Among the companies who ha...
# }
# ---------- >8 ----------
# 2025-04-27T22:00:19.332581 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "companies",
#     "product",
#     "Chinook",
#     "key person",
#     "Dennis Muilenburg"
# ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Among the companies who ha...
#     "output": "\n[\n    \"companies\",\n    \"product\",\n    \"Chinook\",\n    \"key person\",\n...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T22:00:19.333325 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T22:00:19.333512 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Among the companies who has product named Chinook who has a key person as Dennis Mu...
#     "expected_query": "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/keyPeople> <...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Boeing"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T22:00:19.333647 [[Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-98](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Among the companies who has product named Chinook who has a key person as Dennis Mui...
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/keyPeople> <http://dbp...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "f56e456a-79a5-4ad4-9150-eb792f37c398"
#     }
# }
# ---------- >8 ----------
#  10% 99/1000 [13:45<1:33:20,  6.22s/it]2025-04-27T22:00:19.333927 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which country's leader  is Giuseppe Bertello?",
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/leader> <http://dbpedi...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "a4fb142f-5c45-4bb6-adec-a53961cd37b9"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T22:00:19.334092 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Which country's leader  is Giuseppe Bertello?
# ---------- 8< ---------- DATA
# "Which country's leader  is Giuseppe Bertello?"
# ---------- >8 ----------
# 2025-04-27T22:00:19.673478 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Vatican_City'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Vatican_City"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T22:00:19.673724 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Which country's leader  is Giuseppe Bertello?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which country's leader  is...
# }
# ---------- >8 ----------
# 2025-04-27T22:00:23.753675 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "country",
#     "leader",
#     "Giuseppe Bertello"
# ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which country's leader  is...
#     "output": "\n[\n    \"country\",\n    \"leader\",\n    \"Giuseppe Bertello\"\n]"
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T22:00:23.754508 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T22:00:23.754637 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Which country's leader  is Giuseppe Bertello?",
#     "expected_query": "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/leader> <htt...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Vatican_City"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T22:00:23.754772 [[Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-99](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which country's leader  is Giuseppe Bertello?",
#             "SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/leader> <http://dbpedi...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "a4fb142f-5c45-4bb6-adec-a53961cd37b9"
#     }
# }
# ---------- >8 ----------
#  10% 100/1000 [13:49<1:25:10,  5.68s/it]2025-04-27T22:00:23.755168 [[Q-100](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-100](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Who wrote the subsequent work of One Day at a Time (Em's Version) ?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/One_Day_at_a_Time_(Em's_Ve...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "0225797a-597a-4d9b-b455-14d3fcbc1d7b"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T22:00:23.755336 [[Q-100](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-100](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Who wrote the subsequent work of One Day at a Time (Em's Version) ?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/One_Day_at_a_Time_(Em's_Ve...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "0225797a-597a-4d9b-b455-14d3fcbc1d7b"
#     }
# }
# ---------- >8 ----------
#  10% 100/1000 [13:49<2:04:29,  8.30s/it]
# Elapsed Time: 835.30 seconds.  Collected 649416 stack frames (552 unique)
#
# real	13m56.061s
# user	2m7.666s
# sys	0m22.108s

# %% [markdown]
# ## Upload results

# %% [markdown]
# ### Time profile

# %%
import os
import time
if os.path.exists('perf.log'):
  new_perf_path = 'perf-{}.log'.format(int(time.time()))
  os.rename('perf.log', new_perf_path)
  # !rsync -HPrz --mkpath \
    "$new_perf_path" \
    result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/perfs
# Out:
# sending incremental file list
# perf-1745790371.log
#       1,942,284 100%  910.53MB/s    0:00:00 (xfr#1, to-chk=0/1)
# sending incremental file list
# perf-1745791224.log
#       1,665,320 100%    1.52GB/s    0:00:00 (xfr#1, to-chk=0/1)

# %% [markdown]
# ### Logs

# %%
# !rsync -HPrz --mkpath \
  src/experiment-viewer/logs/ \
  result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/logs
# Out:
# sending incremental file list
# .gitignore
#              13 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=1/3)
# log-2025-04-27 21:07:30.100512.jsonl
#       2,044,339 100%  389.93MB/s    0:00:00 (xfr#2, to-chk=0/3)
# sending incremental file list
# .gitignore
#              13 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=2/4)
# log-2025-04-27 21:07:30.100512.jsonl
#       2,044,339 100%    1.90GB/s    0:00:00 (xfr#2, to-chk=1/4)
# log-2025-04-27 21:46:33.788215.jsonl
#       1,404,420 100%  223.23MB/s    0:00:00 (xfr#3, to-chk=0/4)

# %% [markdown]
# ## Cleanup

# %%
# Finish time
# !date
# Out:
# Sun Apr 27 09:46:18 PM UTC 2025
# Sun Apr 27 10:00:31 PM UTC 2025

# %% [markdown]
# ### Stop kernel

# %%
# exit(0)
