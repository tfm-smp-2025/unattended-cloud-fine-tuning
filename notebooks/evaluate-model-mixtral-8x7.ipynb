# %% [markdown]
# # Model evaluation notebook

# %%
# Jupyter version
import ipywidgets as widgets
from IPython.display import display

model_list = [
  "gemma2:2b",
  "gemma2:9b",
  "gemma3:12b",
  "mistral:7b",
  "mixtral:8x7b",
  "phi:2.7b",
  "phi4:14b",
  "deepseek-r1:7b",
]
model_picker = widgets.Dropdown(options=model_list)

# GColab version
MODEL = 'mixtral:8x7b' # @param ["gemma2:2b", "gemma2:9b", "gemma3:12b", "mistral:7b", "mixtral:8x7b", "phi:2.7b", "phi4:14b", "deepseek-r1:7b"] {allow-input: true}
MODEL
# Out:
# 'mixtral:8x7b'

# %%
# Start time
# !date
# Out:
# Sun Apr 27 06:56:20 PM UTC 2025

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install Ollama

# %% [markdown]
# #### Google Colab

# %%
# Google Collab dependencies from: https://github.com/5aharsh/collama
# !sudo apt update
# !sudo apt install -y pciutils
# !sh -c 'if which ollama; then echo Ollama already installed; else curl -fsSL https://ollama.com/install.sh | sh; fi'
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,700 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Get:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,863 kB]
# Fetched 18.3 MB in 4s (4,222 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 35 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 35 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (261 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package pci.ids.
# (Reading database ... 126333 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# #### Docker image
# An ephemeral environment can be prepared with.
#
# ```shell
# docker run -v "${PWD}":/home/jovyan/work -it --rm -p 10000:8888 quay.io/jupyter/scipy-notebook:2025-03-14
# ```

# %% [markdown]
# If on Jupyter Docker image, run
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'apt update && apt install -y pciutils'
# ```

# %% [markdown]
# ##### Install Ollama
# ```shell
# docker exec -it --user=0 <docker_container_name> sh -c 'curl -fsSL https://ollama.com/install.sh | sh'
# ```

# %% [markdown]
# #### Prepare model

# %%
# Code taken from https://github.com/5aharsh/collama
import threading
import subprocess
import time
import socket

MAX_WAIT_SECONDS = 60
OLLAMA_PORT = 11434

def is_ollama_ready():
  s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
  try:
    s.connect(('localhost', OLLAMA_PORT))
    s.shutdown(socket.SHUT_RDWR)
    return True
  except:
    return False


def start_ollama_thread():
  def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])

  thread = threading.Thread(target=run_ollama_serve)
  thread.start()

  print("Waiting for OLLama to be ready...         ")

  for sec in range(MAX_WAIT_SECONDS):
    if is_ollama_ready():
      break
    print("\b\b\b\b\b\b\b\b\b" + "{:3d}s/{:3d}s".format(sec + 1, MAX_WAIT_SECONDS), end='', flush=True)
    time.sleep(1)
  print()

if not is_ollama_ready():
  start_ollama_thread()
# Out:
# Waiting for OLLama to be ready...
#   1s/ 60s

# %%
# !ollama pull "$MODEL"
# Out:
# Streaming output truncated to the last 5000 lines.
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# ...
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling f2dc41fa964b: 100% ▕▏  26 GB/ 26 GB   51 MB/s      0s
# pulling 53d74de0d84c: 100% ▕▏   84 B
# pulling 43070e2d4e53: 100% ▕▏  11 KB
# pulling ed11eda7790d: 100% ▕▏   30 B
# pulling deae14c19dac: 100% ▕▏  486 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ### Prepare code

# %%
from getpass import getpass

def get_secret(prompt, secret_name, secret_input=True):
  try:
    from google.colab import userdata
    result = userdata.get(secret_name)
    assert result is not None
  except:
    if secret_input:
      result = getpass(prompt)
    else:
      result = input(prompt)
  return result

# %%
import os

if not os.path.exists('src'):
  import urllib

  user = get_secret('User name: ', 'TFM_GH_USER')
  password = get_secret('Password: ', 'TFM_GH_TOKEN')
  password = urllib.parse.quote(password) # your password is converted into url format
  repopath = "tfm-smp-2025/fine-tuning"

  # !git clone https://"$user":"$password"@github.com/"$repopath" src

  del password
# Out:
# Cloning into 'src'...
# remote: Enumerating objects: 674, done.
# remote: Counting objects: 100% (256/256), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 674 (delta 172), reused 166 (delta 95), pack-reused 418 (from 1)
# Receiving objects: 100% (674/674), 142.30 KiB | 14.23 MiB/s, done.
# Resolving deltas: 100% (429/429), done.

# %%
# Update code, if needed
# !cd src && git pull
# Out:
# Already up to date.

# %% [markdown]
# #### Dependencies

# %%
# !pip install -q -r src/requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 46.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 89.7 MB/s eta 0:00:00

# %% [markdown]
# ##### NLP model

# %%
try:
  import spacy
  spacy.load("en_core_web_md")
except:
  # !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# #### Credentials

# %% [markdown]
# ##### Result pusher setup

# %%
import os

if (
    (not os.path.exists(os.path.expanduser("~/.ssh/id_rsa")))
    or (not os.path.exists(os.path.expanduser("~/.ssh/known_hosts")))
):
  SSHKEY = get_secret('Result pusher SSH key: ', 'TFM_SSH_PUSHER_KEY')

  # !mkdir ~/.ssh

  # Read locally with `cat ~/.ssh/result-pusher|tr '\n' '$';echo`
  with open(os.path.expanduser("~/.ssh/id_rsa"), 'wt') as f:
    f.write(SSHKEY.replace('$', '\n'))

  # !chmod 0600 ~/.ssh/id_rsa
  # !ssh-keygen -y -f ~/.ssh/id_rsa > ~/.ssh/id_rsa.pub
  # !chmod 0600 ~/.ssh/id_rsa.pub

  # This won't copy the client key (not needed), but it will initialize the server's on the client
  # !ssh-copy-id -i ~/.ssh/id_rsa -o StrictHostKeyChecking=accept-new result-pusher@kb.tfm.codigoparallevar.com

  del SSHKEY
# Out:
# /usr/bin/ssh-copy-id: INFO: Source of key(s) to be installed: "/root/.ssh/id_rsa.pub"
# /usr/bin/ssh-copy-id: INFO: attempting to log in with the new key(s), to filter out any that are already installed
#
# /usr/bin/ssh-copy-id: WARNING: All keys were skipped because they already exist on the remote system.
# 		(if you think this is a mistake, you may want to use -f option)

# %% [markdown]
# ##### Patch SPARQL wrapper to use KB_PASSWORD

# %%
import os
if not os.getenv('KB_PASSWORD'):
  os.environ['KB_PASSWORD'] = get_secret('Password: ', 'TFM_KB_ADMIN_PASS')

# !export KB_PASSWORD=$KB_PASSWORD

# %%
# !sed 's/from urllib.request import/import base64, os\nfrom urllib.request import/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'
# !sed 's/request = self._createRequest()/request = self._createRequest()\n        base64string = base64.b64encode("{}:{}".format("admin", os.environ["KB_PASSWORD"]).encode())\n        request.add_header("Authorization", "Basic " + base64string.decode())/' \
   -i '/usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py'

# %% [markdown]
# ##### Setup WEAVIATE API KEY

# %%
import os
if not os.getenv('WEAVIATE_API_KEY'):
  os.environ['WEAVIATE_API_KEY'] = get_secret('Password: ', 'TFM_VECTOR_DB_ADMIN_APIKEY')

# !export WEAVIATE_API_KEY=$WEAVIATE_API_KEY

# %% [markdown]
# ### Pull datasets

# %%
# !python3 src/scripts/pull_datasets.py
# Out:
# qald-9 | Unified dataset...
#   ↓  Downloading qald-9 dataset
#   ✔  qald-9 dataset ready
#
# beastiary | Unified dataset...
#   ↓  Downloading beastiary dataset
#   ✔  beastiary dataset ready
#
# VQuAnDA | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 1.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# LC-QuAD 2.0 | Split dataset...
#   ↓  Downloading train file
#   ✔  Train file ready
#   ↓  Downloading test file
#   ✔  Test file ready
#
# WebQuestions SP | Unified dataset...
#   ↓  Downloading WebQuestions SP dataset
#   ✔  WebQuestions SP dataset ready

# %% [markdown]
# ## Run evaluation

# %%
# Prepare profiler
# !pip install -q git+https://github.com/nickodell/python-flamegraph.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for flamegraph (setup.py) ... done

# %%
assert MODEL != ''

if not is_ollama_ready():
  start_ollama_thread()

# !time WEAVIATE_HOST=kb.tfm.codigoparallevar.com \
    python3 \
    -m flamegraph -o perf.log \
    src/src/as_script.py \
    --seed 42 \
    test --models="$MODEL" \
    --sparql-server 'http://kb.tfm.codigoparallevar.com' \
    --sample 10 \
    --dataset 'LC-QuAD 1.0'
# Out:
# Namespace(script_file='src/src/as_script.py', script_args=['--seed', '42', 'test', '--models=mixtral:8x7b', '--sparql-server', 'http://kb.tfm.codigoparallevar.com', '--sample', '10', '--dataset', 'LC-QuAD 1.0'], output=<_io.TextIOWrapper name='perf.log' mode='w' encoding='utf-8'>, interval=0.001, collapse_recursion=False, filter=None, format='%(threadname)s`%(fun)s')
# WARNING:root:MISTRAL_API_KEY not defined, disabling models: ['open-mistral-7b']
# 2025-04-27T19:01:43.427595 info:	 Starting operation
#   0% 0/1000 [00:00<?, ?it/s]2025-04-27T19:01:43.451288 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sanno...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Marine_Corps_Air_Station_...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "11567b27-d04c-4205-ad56-ef4979a18e77"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:01:43.451523 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sanno hotel /'
# ---------- 8< ---------- DATA
# "Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sanno hotel /'"
# ---------- >8 ----------
# 2025-04-27T19:01:43.847459 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/United_States_Navy'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/United_States_Navy"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T19:01:43.847624 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sanno hotel /'
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which architect of Marine ...
# }
# ---------- >8 ----------
# 2025-04-27T19:02:16.488981 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: Sure, I'd be happy to help you extract the nouns from that sentence. Here they are:
#
# ```json
# [
#     "architect",
#     "Marine Corps Air Station Kaneohe Bay",
#     "tenant",
#
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which architect of Marine ...
#     "output": "Sure, I'd be happy to help you extract the nouns from that sentence. Here they are...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T19:02:16.489995 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:02:16.490127 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sann...
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Marine_Corps_Ai...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/United_States_Navy"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:02:16.490254 [[Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-0](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which architect of Marine Corps Air Station Kaneohe Bay was also tenant of New Sanno...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Marine_Corps_Air_Station_...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "11567b27-d04c-4205-ad56-ef4979a18e77"
#     }
# }
# ---------- >8 ----------
#   0% 1/1000 [00:33<9:10:06, 33.04s/it]2025-04-27T19:02:16.490546 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which sects people are part of local political parties which fall under the Internat...
#             "SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/property/international> <http://...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "9fb0c518-3537-4d7e-bfac-b42e0e82140d"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:02:16.490927 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Which sects people are part of local political parties which fall under the International Muslim Brotherhood?
# ---------- 8< ---------- DATA
# "Which sects people are part of local political parties which fall under the International Muslim...
# ---------- >8 ----------
# 2025-04-27T19:02:16.887505 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Islam'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Sunni_Islam'}}, {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Wahhabism'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Islam"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Sunni_Islam"
#         }
#     },
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Wahhabism"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T19:02:16.887708 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Which sects people are part of local political parties which fall under the International Muslim Brotherhood?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which sects people are par...
# }
# ---------- >8 ----------
# 2025-04-27T19:02:22.126000 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:  [
#     "sects",
#     "people",
#     "local",
#     "political parties",
#     "International Muslim Brotherhood"
#   ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Which sects people are par...
#     "output": " [\n    \"sects\",\n    \"people\",\n    \"local\",\n    \"political parties\",\n ...
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T19:02:22.126919 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:02:22.127052 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Which sects people are part of local political parties which fall under the Interna...
#     "expected_query": "SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/property/international...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Islam"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Sunni_Islam"
#             }
#         },
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Wahhabism"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:02:22.127216 [[Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-1](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which sects people are part of local political parties which fall under the Internat...
#             "SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/property/international> <http://...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "9fb0c518-3537-4d7e-bfac-b42e0e82140d"
#     }
# }
# ---------- >8 ----------
#   0% 2/1000 [00:38<4:41:26, 16.92s/it]2025-04-27T19:02:22.127709 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "List common systems are developed by of the Google Videos and written by of the Goog...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Google_Videos> <http://db...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "29be4f88-bc2d-4eb6-8abd-1cf9daf460d0"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:02:22.127896 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: List common systems are developed by of the Google Videos and written by of the Google Web Toolkit ?
# ---------- 8< ---------- DATA
# "List common systems are developed by of the Google Videos and written by of the Google Web Toolk...
# ---------- >8 ----------
# 2025-04-27T19:02:22.517062 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Google'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Google"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T19:02:22.517220 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > List common systems are developed by of the Google Videos and written by of the Google Web Toolkit ?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> List common systems are de...
# }
# ---------- >8 ----------
# 2025-04-27T19:02:26.890586 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# [
#     "systems",
#     "Google Videos",
#     "Google Web Toolkit
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> List common systems are de...
#     "output": "\n[\n    \"systems\",\n    \"Google Videos\",\n    \"Google Web Toolkit\n]\n```"
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T19:02:26.891546 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:02:26.891711 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "List common systems are developed by of the Google Videos and written by of the Goo...
#     "expected_query": " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Google_Videos> ...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Google"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:02:26.892011 [[Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-2](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "List common systems are developed by of the Google Videos and written by of the Goog...
#             " SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Google_Videos> <http://db...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "29be4f88-bc2d-4eb6-8abd-1cf9daf460d0"
#     }
# }
# ---------- >8 ----------
#   0% 3/1000 [00:43<3:08:55, 11.37s/it]2025-04-27T19:02:26.892467 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "For which games are Sam Loyd and Eric Schiller both famous?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Sam_Loyd> <http://dbpedia....
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "aa7aba7d-9694-4a22-aa45-91d0be4f7a89"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:02:26.892675 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: For which games are Sam Loyd and Eric Schiller both famous?
# ---------- 8< ---------- DATA
# "For which games are Sam Loyd and Eric Schiller both famous?"
# ---------- >8 ----------
# 2025-04-27T19:02:27.285716 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Chess'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Chess"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T19:02:27.285969 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > For which games are Sam Loyd and Eric Schiller both famous?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> For which games are Sam Lo...
# }
# ---------- >8 ----------
# 2025-04-27T19:02:31.479192 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:  [
#     "games",
#     "Sam Loyd",
#     "Eric Schiller"
#   ]
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> For which games are Sam Lo...
#     "output": " [\n    \"games\",\n    \"Sam Loyd\",\n    \"Eric Schiller\"\n  ]"
# }
# ---------- >8 ----------
# Entities: []
# 2025-04-27T19:02:31.480155 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 74, in translate
#     entities = json.loads(entities_str[-1].content)
#                           ~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:02:31.480293 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "For which games are Sam Loyd and Eric Schiller both famous?",
#     "expected_query": "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Sam_Loyd> <http:...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Chess"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:02:31.480435 [[Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-3](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "For which games are Sam Loyd and Eric Schiller both famous?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Sam_Loyd> <http://dbpedia....
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "aa7aba7d-9694-4a22-aa45-91d0be4f7a89"
#     }
# }
# ---------- >8 ----------
#   0% 4/1000 [00:48<2:24:17,  8.69s/it]2025-04-27T19:02:31.480730 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Is Peter Piper Pizza in the pizza industry?",
#             "ASK WHERE { <http://dbpedia.org/resource/Peter_Piper_Pizza> <http://dbpedia.org/onto...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "3e51852e-7fa0-4339-99a5-07fcff5eece0"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:02:31.481033 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Is Peter Piper Pizza in the pizza industry?
# ---------- 8< ---------- DATA
# "Is Peter Piper Pizza in the pizza industry?"
# ---------- >8 ----------
# 2025-04-27T19:02:31.874710 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: True
# ---------- 8< ---------- DATA
# true
# ---------- >8 ----------
# 2025-04-27T19:02:31.874867 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Is Peter Piper Pizza in the pizza industry?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Is Peter Piper Pizza in th...
# }
# ---------- >8 ----------
# 2025-04-27T19:02:51.706328 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: Sure, I'd be happy to help you extract the nouns from that sentence. Here they are:
#
# ```json
# ["Peter", "Piper", "Pizza", "industry"]
# ```
#
# However, I would like to clarify that "Peter Piper" is often used as a single entity in phrases and titles, such as the tongue twister "Peter Piper picked a peck of pickled peppers". But in your sentence, it seems you're using it to refer to a possible entity name, like a pizza restaurant.
#
# Also, I noticed you mentioned SPARQL verbs. If you're planning to use these nouns in a SPARQL query, you might need to ensure they correspond to actual entities in your RDF dataset.
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Is Peter Piper Pizza in th...
#     "output": "Sure, I'd be happy to help you extract the nouns from that sentence. Here they are...
# }
# ---------- >8 ----------
# Entities: [CodeBlock(language='json', content='["Peter", "Piper", "Pizza", "industry"]\n')]
# 2025-04-27T19:03:00.416410 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "Peter" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "Peter",
#     "singular": true
# }
# ---------- >8 ----------
# 2025-04-27T19:03:02.074135 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "Piper" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "Piper",
#     "singular": true
# }
# ---------- >8 ----------
# 2025-04-27T19:03:03.961041 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "Pizza" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "Pizza",
#     "singular": true
# }
# ---------- >8 ----------
# 2025-04-27T19:03:05.620977 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "industry" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "industry",
#     "singular": true
# }
# ---------- >8 ----------
#
# Finding singular elements:   0% 0/4 [00:00<?, ?it/s]
# Finding singular elements:  25% 1/4 [00:02<00:08,  2.75s/it]
# Finding singular elements:  50% 2/4 [00:04<00:03,  1.90s/it]
# Finding singular elements:  75% 3/4 [00:05<00:01,  1.62s/it]
# Finding singular elements: 100% 4/4 [00:06<00:00,  1.66s/it]
# 2025-04-27T19:03:18.890226 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Find relations outgoing from nodes: 81 nodes & 40 predicates
# ---------- 8< ---------- DATA
# {
#     "predicates": [
#         "http://dbpedia.org/ontology/splitFromParty",
#         "http://dbpedia.org/ontology/sisterNewspaper",
#         "http://dbpedia.org/property/producers",
#         "http://dbpedia.org/property/minister1Name",
#         "http://dbpedia.org/property/sisterStations",
#         "http://dbpedia.org/ontology/cuisine",
#         "http://dbpedia.org/ontology/ingredientName",
#         "http://dbpedia.org/property/rector",
#         "http://dbpedia.org/ontology/productionEndYear",
#         "http://dbpedia.org/ontology/personFunction",
#         "http://dbpedia.org/property/construction",
#         "http://dbpedia.org/ontology/ingredient",
#         "http://dbpedia.org/property/sisterNewspapers",
#         "http://dbpedia.org/ontology/sisterStation",
#         "http://dbpedia.org/ontology/personName",
#         "http://dbpedia.org/property/sisterCollege",
#         "http://dbpedia.org/property/p",
#         "http://dbpedia.org/ontology/constructionMaterial",
#         "http://dbpedia.org/property/feastDay",
#         "http://dbpedia.org/property/industry",
#         "http://dbpedia.org/property/carbohydrate",
#         "http://dbpedia.org/ontology/feastDay",
#         "http://dbpedia.org/property/chorus",
#         "http://dbpedia.org/ontology/person",
#         "http://dbpedia.org/property/foodType",
#         "http://dbpedia.org/property/structuralEngineer",
#         "http://dbpedia.org/ontology/numberOfRestaurants",
#         "http://dbpedia.org/property/iata",
#         "http://dbpedia.org/ontology/notableCommander",
#         "http://dbpedia.org/ontology/waterwayThroughTunnel",
#         "http://dbpedia.org/property/production",
#         "http://dbpedia.org/ontology/rector",
#         "http://dbpedia.org/ontology/sisterCollege",
#         "http://dbpedia.org/property/notableCommanders",
#         "http://dbpedia.org/property/father",
#         "http://dbpedia.org/property/numberOfRestaurants",
#         "http://dbpedia.org/property/b\u00fcrgermeistertitel",
#         "http://dbpedia.org/ontology/industry",
#     ...
# }
# ---------- >8 ----------
# 2025-04-27T19:03:19.545206 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 1/3):
# Given that the entities being referenced are:
#
# ```json
# {
#     "Piper": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/Piper_Aircraft",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/industry",
#                     "http://dbpedia.org/property/industry"
#                 ]
#             }
#         ]
#     },
#     "industry": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/American_Industries",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/industry",
#                     "http://dbpedia.org/property/industry"
#                 ]
#             }
#         ]
#     },
#     "Pizza": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/Pizza_Pizza",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/industry",
#                     "http://dbpedia.org/property/industry"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Pizza",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/ingredient",
#                     "http://dbpedia.org/ontology/ingredientName"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Sushi_pizza",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/ingredient",
#                     "http://dbpedia.org/ontology/ingredientName"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Pizza_73",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/industry",
#                     "http://dbpedia.org/property/industry"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Cartoon_Pizza",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/industry",
#                     "http://dbpedia.org/property/industry"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Pizza-ghetti",
#                 "predicates": [
#                     "http://dbpedia.org/ontology/ingredient",
#                     "http://dbpedia.org/ontology/ingredientName"
#                 ]
#             }
#         ]
#     }
# }
# ```
#
# This are some examples on how the available properties can be used:
#
# ### Subject: <http://dbpedia.org/resource/Piper_Aircraft> ; Predicate: <http://dbpedia.org/ontology/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Piper_Aircraft> <http://dbpedia.org/ontology/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Piper_Aircraft> ; Predicate: <http://dbpedia.org/property/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Piper_Aircraft> <http://dbpedia.org/property/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/American_Industries> ; Predicate: <http://dbpedia.org/ontology/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/American_Industries> <http://dbpedia.org/ontology/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/American_Industries> ; Predicate: <http://dbpedia.org/property/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/American_Industries> <http://dbpedia.org/property/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza_Pizza> ; Predicate: <http://dbpedia.org/ontology/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza_Pizza> <http://dbpedia.org/ontology/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza_Pizza> ; Predicate: <http://dbpedia.org/property/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza_Pizza> <http://dbpedia.org/property/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza> ; Predicate: <http://dbpedia.org/ontology/ingredient>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza> <http://dbpedia.org/ontology/ingredient> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza> ; Predicate: <http://dbpedia.org/ontology/ingredientName>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza> <http://dbpedia.org/ontology/ingredientName> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Sushi_pizza> ; Predicate: <http://dbpedia.org/ontology/ingredient>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Sushi_pizza> <http://dbpedia.org/ontology/ingredient> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Sushi_pizza> ; Predicate: <http://dbpedia.org/ontology/ingredientName>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Sushi_pizza> <http://dbpedia.org/ontology/ingredientName> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza_73> ; Predicate: <http://dbpedia.org/ontology/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza_73> <http://dbpedia.org/ontology/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza_73> ; Predicate: <http://dbpedia.org/property/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza_73> <http://dbpedia.org/property/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Cartoon_Pizza> ; Predicate: <http://dbpedia.org/ontology/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Cartoon_Pizza> <http://dbpedia.org/ontology/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Cartoon_Pizza> ; Predicate: <http://dbpedia.org/property/industry>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Cartoon_Pizza> <http://dbpedia.org/property/industry> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza-ghetti> ; Predicate: <http://dbpedia.org/ontology/ingredient>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza-ghetti> <http://dbpedia.org/ontology/ingredient> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Pizza-ghetti> ; Predicate: <http://dbpedia.org/ontology/ingredientName>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Pizza-ghetti> <http://dbpedia.org/ontology/ingredientName> ?object }
# ```
#
# Of the ones given, which predicates will be useful to solve it?
#
# Consider it's better to query directly on IRIs and avoid filtering whenever possible. DO NOT generate any query yet.
#
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"Piper\": {\n  ...
# }
# ---------- >8 ----------
# 2025-04-27T19:03:38.915854 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: 1. For finding industries related to Pizza Hut, Domino's Pizza, and Little Caesars:
# 	* http://dbpedia.org/ontology/industry
# 	* http://dbpedia.org/property/industry
# 2. For listing ingredients of Pizza and Sushi Pizza:
# 	* http://dbpedia.org/ontology/ingredient
# 3. For getting the names of ingredients for Pizza-ghetti:
# 	* http://dbpedia.org/ontology/ingredientName
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"Piper\": {\n  ...
#     "output": "1. For finding industries related to Pizza Hut, Domino's Pizza, and Little Caesars...
# }
# ---------- >8 ----------
# 2025-04-27T19:03:38.916271 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 2/3): What are the subject IRIs that will be handy to solve this query? STILL DO NOT generate any query yet.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:02.566878 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: 1. For finding industries related to Pizza Hut, Domino's Pizza, and Little Caesars:
# 	* http://dbpedia.org/resource/Pizza_Hut
# 	* http://dbpedia.org/resource/Dominos_Pizza
# 	* http://dbpedia.org/resource/Little_Caesars
# 2. For listing ingredients of Pizza and Sushi Pizza:
# 	* http://dbpedia.org/resource/Pizza
# 	* http://dbpedia.org/resource/Sushi_pizza
# 3. For getting the names of ingredients for Pizza-ghetti:
# 	* http://dbpedia.org/resource/Pizza-ghetti
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
#     "output": "1. For finding industries related to Pizza Hut, Domino's Pizza, and Little Caesars...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:02.567195 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 3/3):
# Construct a SPARQL query to solve it on a single query, keep it simple and avoid unnecessary conditions. If it's an item list just do a SELECT, but if it's numeric you might need to use a verb like COUNT(), and if it's boolean you might need to use ASK.
#
# Remember to avoid querying by label, use the IRIs and relations presented before, not others. DO NOT even use common types like `name` or `type` unless they were explicitly allowed.
#
# Query to solve:
# > Is Peter Piper Pizza in the pizza industry?
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:15.536700 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: ```SPARQL
# SELECT ?industry
# WHERE {
#     <http://dbpedia.org/resource/Peter_Piper_Pizza> <http://dbpedia.org/ontology/industry> ?industry .
# }
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
#     "output": "```SPARQL\nSELECT ?industry\nWHERE {\n    <http://dbpedia.org/resource/Peter_Piper...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:15.537940 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 320, in translate
#     final_query = self._generate_sparql_query(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 446, in _generate_sparql_query
#     return sparql_code_blocks[-1]
#            ~~~~~~~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:04:15.538169 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Is Peter Piper Pizza in the pizza industry?",
#     "expected_query": "ASK WHERE { <http://dbpedia.org/resource/Peter_Piper_Pizza> <http://dbpedi...
#     "expected_result": true,
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:04:15.538297 [[Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-4](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Is Peter Piper Pizza in the pizza industry?",
#             "ASK WHERE { <http://dbpedia.org/resource/Peter_Piper_Pizza> <http://dbpedia.org/onto...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "3e51852e-7fa0-4339-99a5-07fcff5eece0"
#     }
# }
# ---------- >8 ----------
#   0% 5/1000 [02:32<11:54:26, 43.08s/it]2025-04-27T19:04:15.538586 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Name the artist who made Dream Dancing and is often associated with Joe Pass?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Joe_Pass> <http://dbpedia....
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "e4b6129c-40d9-4ea1-b734-c585204708d8"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:04:15.538736 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Input: Name the artist who made Dream Dancing and is often associated with Joe Pass?
# ---------- 8< ---------- DATA
# "Name the artist who made Dream Dancing and is often associated with Joe Pass?"
# ---------- >8 ----------
# 2025-04-27T19:04:15.936375 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Expected query result: [{'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ella_Fitzgerald'}}]
# ---------- 8< ---------- DATA
# [
#     {
#         "uri": {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Ella_Fitzgerald"
#         }
#     }
# ]
# ---------- >8 ----------
# 2025-04-27T19:04:15.936529 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM: Extract the nouns from this natural language query.
#
# > Name the artist who made Dream Dancing and is often associated with Joe Pass?
#
# Let's reason step by step. Identify the nouns on the query, skip the ones that can be solved by a SPARQL verb (ignore, for example, "count" or "number of"), and output a json list like this.
#
# ```json
# [
#     "entity1",
#     "entity2",
#     ...
#     "entityN"
# ]
# ```
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Name the artist who made D...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:26.708097 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: Sure, I'd be happy to help you extract the nouns from that sentence. Here they are:
#
# ```json
# [
#     "artist",
#     "Dream Dancing",
#     "Joe Pass"
# ]
# ```
#
# These are the key nouns in your sentence. The sentence is asking for the "artist" who made "Dream Dancing" and is often associated with "Joe Pass".
# ---------- 8< ---------- DATA
# {
#     "type": "get_entities_in_query",
#     "input": "Extract the nouns from this natural language query.\n\n> Name the artist who made D...
#     "output": "Sure, I'd be happy to help you extract the nouns from that sentence. Here they are...
# }
# ---------- >8 ----------
# Entities: [CodeBlock(language='json', content='[\n    "artist",\n    "Dream Dancing",\n    "Joe Pass"\n]\n')]
# 2025-04-27T19:04:32.255491 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "artist" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "artist",
#     "singular": true
# }
# ---------- >8 ----------
# 2025-04-27T19:04:33.900290 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	WARNING:	 Expected 1 item from phrase: "Dream Dancing", found:
#     Dream; NN; noun, singular or mass
#     Dancing; NN; noun, singular or mass
# 2025-04-27T19:04:33.900489 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "Dream Dancing" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "Dream Dancing",
#     "singular": true
# }
# ---------- >8 ----------
# 2025-04-27T19:04:35.535542 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	WARNING:	 Expected 1 item from phrase: "Joe Pass", found:
#     Joe; NNP; noun, proper singular
#     Pass; NNP; noun, proper singular
# 2025-04-27T19:04:35.535729 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Checking if "Joe Pass" is singular
# ---------- 8< ---------- DATA
# {
#     "input": "Joe Pass",
#     "singular": true
# }
# ---------- >8 ----------
#
# Finding singular elements:   0% 0/3 [00:00<?, ?it/s]
# Finding singular elements:  33% 1/3 [00:01<00:02,  1.30s/it]
# Finding singular elements:  67% 2/3 [00:02<00:01,  1.30s/it]
# Finding singular elements: 100% 3/3 [00:03<00:00,  1.31s/it]
# 2025-04-27T19:04:43.338512 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Find relations outgoing from nodes: 61 nodes & 30 predicates
# ---------- 8< ---------- DATA
# {
#     "predicates": [
#         "http://dbpedia.org/ontology/coverArtist",
#         "http://dbpedia.org/property/eyeColour",
#         "http://dbpedia.org/property/passPercent",
#         "http://dbpedia.org/ontology/distanceToCharingCross",
#         "http://dbpedia.org/property/passSystem",
#         "http://dbpedia.org/property/animator",
#         "http://dbpedia.org/property/artist",
#         "http://dbpedia.org/property/eyecolour",
#         "http://dbpedia.org/property/choreographer",
#         "http://dbpedia.org/ontology/animator",
#         "http://dbpedia.org/ontology/crosses",
#         "http://dbpedia.org/ontology/artist",
#         "http://dbpedia.org/property/orbits",
#         "http://dbpedia.org/ontology/neighbourConstellations",
#         "http://dbpedia.org/ontology/orbits",
#         "http://dbpedia.org/property/carries",
#         "http://rdvocab.info/RDARelationshipsWEMI/manifestationOfWork",
#         "http://dbpedia.org/property/passYear",
#         "http://dbpedia.org/ontology/barPassRate",
#         "http://dbpedia.org/property/throws",
#         "http://dbpedia.org/property/crosses",
#         "http://dbpedia.org/property/barPassRate",
#         "http://dbpedia.org/ontology/musicalArtist",
#         "http://dbpedia.org/ontology/illustrator",
#         "http://dbpedia.org/property/illustrator",
#         "http://dbpedia.org/property/movement",
#         "http://dbpedia.org/property/coverArtist",
#         "http://dbpedia.org/ontology/choreographer",
#         "http://dbpedia.org/ontology/gameArtist",
#         "http://dbpedia.org/ontology/movement"
#     ],
#     "nodes": [
#         "http://dbpedia.org/resource/Art_Green_(artist)",
#         "http://dbpedia.org/resource/Dream_Dancing",
#         "http://dbpedia.org/class/yago/ArtisticMovement108466643",
#         "http://dbpedia.org/ontology/MusicalArtist",
#         "http://dbpedia.org/resource/Joe's_Blues_(Joe_Pass_album)",
#         "http://umbel.org/umbel/rc/Artist",
#     ...
# }
# ---------- >8 ----------
# 2025-04-27T19:04:43.899255 [[Q-5](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 1/3):
# Given that the entities being referenced are:
#
# ```json
# {
#     "Joe Pass": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/Virtuoso_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Joe's_Blues_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Resonance_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Unforgettable_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Simplicity_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Live_at_Donte's_(Joe_Pass_album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Chops_(Joe_Pass_album)",
# ...
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Who's_Who%3F",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             }
#         ]
#     },
#     "creator": {
#         "subjects": [
#             {
#                 "iri": "http://dbpedia.org/resource/Creator_(song)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/musicalArtist"
#                 ]
#             },
#             {
#                 "iri": "http://dbpedia.org/resource/Creator_(album)",
#                 "predicates": [
#                     "http://dbpedia.org/property/artist",
#                     "http://dbpedia.org/ontology/artist"
#                 ]
#             }
#         ]
#     }
# }
# ```
#
# This are some examples on how the available properties can be used:
#
# ### Subject: <http://dbpedia.org/resource/Alsophilinae> ; Predicate: <http://dbpedia.org/property/familia>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Alsophilinae> <http://dbpedia.org/property/familia> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Yes_and_Also_Yes> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Yes_and_Also_Yes> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Yes_and_Also_Yes> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Yes_and_Also_Yes> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Alsodryas> ; Predicate: <http://dbpedia.org/property/familia>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Alsodryas> <http://dbpedia.org/property/familia> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Alsodeiopsis> ; Predicate: <http://dbpedia.org/property/familia>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Alsodeiopsis> <http://dbpedia.org/property/familia> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/L'Enfant_a_la_tasse> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/L'Enfant_a_la_tasse> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Enfant_de_la_ville> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Enfant_de_la_ville> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Enfant_de_la_ville> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Enfant_de_la_ville> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Une_enfant_du_siècle> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Une_enfant_du_siècle> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Une_enfant_du_siècle> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Une_enfant_du_siècle> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Made_Who_(song)> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Made_Who_(song)> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Made_Who_(song)> ; Predicate: <http://dbpedia.org/ontology/musicalArtist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Made_Who_(song)> <http://dbpedia.org/ontology/musicalArtist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Knows_Who> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Knows_Who> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Knows_Who> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Knows_Who> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Made_Who> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Made_Who> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who_Made_Who> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who_Made_Who> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who's_Who%3F> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who's_Who%3F> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Who's_Who%3F> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Who's_Who%3F> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Creator_(song)> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Creator_(song)> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Creator_(song)> ; Predicate: <http://dbpedia.org/ontology/musicalArtist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Creator_(song)> <http://dbpedia.org/ontology/musicalArtist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Creator_(album)> ; Predicate: <http://dbpedia.org/property/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Creator_(album)> <http://dbpedia.org/property/artist> ?object }
# ```
#
# ### Subject: <http://dbpedia.org/resource/Creator_(album)> ; Predicate: <http://dbpedia.org/ontology/artist>
#
# ```sparql
# SELECT DISTINCT ?object WHERE { <http://dbpedia.org/resource/Creator_(album)> <http://dbpedia.org/ontology/artist> ?object }
# ```
#
# Of the ones given, which predicates will be useful to solve it?
#
# Consider it's better to query directly on IRIs and avoid filtering whenever possible. DO NOT generate any query yet.
#
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"also\": {\n   ...
# }
# ---------- >8 ----------
# 2025-04-27T19:08:05.298612 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: 1. <http://dbpedia.org/ontology/artist>
# 2. <http://dbpedia.org/property/artist>
# 3. <http://dbpedia.org/ontology/musicalArtist>
#
# These three predicates are likely to be useful in solving the problem, as they directly relate to artists or musicians, which seems to be the primary subject of interest in the given IRIs. Querying with these predicates will help avoid filtering and provide more direct results.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_1_of_3",
#     "input": "\nGiven that the entities being referenced are:\n\n```json\n{\n    \"also\": {\n   ...
#     "output": "1. <http://dbpedia.org/ontology/artist>\n2. <http://dbpedia.org/property/artist>\n...
# }
# ---------- >8 ----------
# 2025-04-27T19:08:05.299051 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 2/3): What are the subject IRIs that will be handy to solve this query? STILL DO NOT generate any query yet.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
# }
# ---------- >8 ----------
# 2025-04-27T19:08:38.315373 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response: 1. <http://dbpedia.org/resource/Who_Made_Who>
# 2. <http://dbpedia.org/resource/Who_Made_Who_(album)>
# 3. <http://dbpedia.org/resource/Who_Made_Who_(song)>
# 4. <http://dbpedia.org/resource/Creator_(song)>
# 5. <http://dbpedia.org/resource/Creator_(album)>
# 6. <http://dbpedia.org/resource/Who's_Who%3F> (This may be a song or a band, so it could be useful)
# 7. <http://dbpedia.org/resource/Who_Knows_Who> (Similar to the above, this might be relevant)
# 8. <http://dbpedia.org/resource/Who_Made_Who_(band)> (If such an IRI exists, it would be useful)
#
# These subject IRIs are chosen because they directly relate to the entities that seem to be bands or musicians, based on the given IRIs. Using these subjects with the previously identified predicates will likely yield relevant results.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_2_of_3",
#     "input": "What are the subject IRIs that will be handy to solve this query? STILL DO NOT gene...
#     "output": "1. <http://dbpedia.org/resource/Who_Made_Who>\n2. <http://dbpedia.org/resource/Who...
# }
# ---------- >8 ----------
# 2025-04-27T19:08:38.315653 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Query LLM (CoT 3/3):
# Construct a SPARQL query to solve it on a single query, keep it simple and avoid unnecessary conditions. If it's an item list just do a SELECT, but if it's numeric you might need to use a verb like COUNT(), and if it's boolean you might need to use ASK.
#
# Remember to avoid querying by label, use the IRIs and relations presented before, not others. DO NOT even use common types like `name` or `type` unless they were explicitly allowed.
#
# Query to solve:
# > Who created the Women in the Garden and also the L'Enfant a la tasse ?
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
# }
# ---------- >8 ----------
# 2025-04-27T19:09:23.108453 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 LLM response:
# To answer the question, "Who created the Women in the Garden and also the L'Enfant a la tasse?", we need to find an artist who painted both of these paintings. However, based on the provided IRIs, there is no direct relationship between them and any artist.
#
# However, if we assume that 'Women in the Garden' refers to the painting by Jean-Honoré Fragonard and 'L'Enfant a la tasse' also refers to a painting by him (which I found in a quick Google search), then we can construct a SPARQL query as follows:
#
# ```
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX dbpprop: <http://dbpedia.org/property/>
# PREFIX dbpo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT ?artist WHERE {
#   {
#     <http://dbpedia.org/resource/Women_in_the_Garden_(painting)> dct:creator ?artist .
#     ?artist a dbpo:Artist .
#   }
#   UNION
#   {
#     <http://dbpedia.org/resource/L'Enfant_a_la_tasse> dct:creator ?artist .
#     ?artist a dbpo:Artist .
#   }
# }
# ```
#
# This query will return any artist who created either of the two paintings, and if Fragonard is returned as a result, then we have our answer. However, please note that this assumes certain things about the provided IRIs, which might not be accurate in a real-world scenario.
# ---------- 8< ---------- DATA
# {
#     "type": "generate_sparql_query_cot_3_of_3",
#     "input": "\nConstruct a SPARQL query to solve it on a single query, keep it simple and avoid ...
#     "output": "\nTo answer the question, \"Who created the Women in the Garden and also the L'Enf...
# }
# ---------- >8 ----------
# 2025-04-27T19:09:23.109721 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	ERROR:	 EXCEPTION
# ---------- 8< ---------- EXCEPTION
# Traceback (most recent call last):
#
#   File "/content/src/src/tester.py", line 114, in run_test
#     result = translator.translate(question.question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 320, in translate
#     final_query = self._generate_sparql_query(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/content/src/src/translators/prompt_based_with_search.py", line 446, in _generate_sparql_query
#     return sparql_code_blocks[-1]
#            ~~~~~~~~~~~~~~~~~~^^^^
#
# IndexError: list index out of range
#
# ---------- >8 ----------
# 2025-04-27T19:09:23.110019 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Test result: error
# ---------- 8< ---------- DATA
# {
#     "input": "Who created the Women in the Garden and also the L'Enfant a la tasse ?",
#     "expected_query": "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Women_in_the_Gar...
#     "expected_result": [
#         {
#             "uri": {
#                 "type": "uri",
#                 "value": "http://dbpedia.org/resource/Claude_Monet"
#             }
#         }
#     ],
#     "result": "error"
# }
# ---------- >8 ----------
# 2025-04-27T19:09:23.110248 [[Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-9](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Who created the Women in the Garden and also the L'Enfant a la tasse ?",
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Women_in_the_Garden> <http...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "2b64fb6a-81f0-493c-a5e4-59640a2a76f6"
#     }
# }
# ---------- >8 ----------
#   1% 10/1000 [07:39<17:40:41, 64.28s/it]2025-04-27T19:09:23.110577 [[Q-10](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Entering context: [Q-10](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which famous horserace has seen both Fergie sutherland and the illustrious War of At...
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/War_Of_Attrition_(horse)> ...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "439ff4f0-91dc-4961-adb2-1fc19d08ddf2"
#     }
# }
# ---------- >8 ----------
# 2025-04-27T19:09:23.110777 [[Q-10](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0]	INFO:	 Leaving context: [Q-10](mixtral:8x7b on Ollama + prompt & search) DATASET: LC-QuAD 1.0
# ---------- 8< ---------- DATA
# {
#     "parent": "Root context",
#     "parameters": {
#         "translator": {
#             "model_name": "mixtral:8x7b"
#         },
#         "question": [
#             "Which famous horserace has seen both Fergie sutherland and the illustrious War of At...
#             "SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/War_Of_Attrition_(horse)> ...
#             null
#         ],
#         "dataset": {
#             "name": "LC-QuAD 1.0",
#             "sparql_endpoint": "dbpedia_2016_04"
#         },
#         "id": "439ff4f0-91dc-4961-adb2-1fc19d08ddf2"
#     }
# }
# ---------- >8 ----------
#   1% 10/1000 [07:39<12:38:26, 45.97s/it]
# Elapsed Time: 466.46 seconds.  Collected 341938 stack frames (740 unique)
#
# real	7m47.713s
# user	1m38.403s
# sys	0m14.912s

# %% [markdown]
# ## Upload results

# %% [markdown]
# ### Time profile

# %%
import os
import time
if os.path.exists('perf.log'):
  new_perf_path = 'perf-{}.log'.format(int(time.time()))
  os.rename('perf.log', new_perf_path)
  # !rsync -HPrz --mkpath \
    "$new_perf_path" \
    result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/perfs
# Out:
# sending incremental file list
# perf-1745780964.log
#       1,792,152 100%  838.94MB/s    0:00:00 (xfr#1, to-chk=0/1)

# %% [markdown]
# ### Logs

# %%
# !rsync -HPrz --mkpath \
  src/experiment-viewer/logs/ \
  result-pusher@kb.tfm.codigoparallevar.com:experiment-viewer/logs
# Out:
# sending incremental file list
# .gitignore
#              13 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=1/3)
# log-2025-04-27 19:01:43.427547.jsonl
#         286,387 100%  273.12MB/s    0:00:00 (xfr#2, to-chk=0/3)

# %% [markdown]
# ## Cleanup

# %%
# Finish time
# !date
# Out:
# Sun Apr 27 07:09:32 PM UTC 2025

# %% [markdown]
# ### Stop kernel

# %%
# exit(0)
